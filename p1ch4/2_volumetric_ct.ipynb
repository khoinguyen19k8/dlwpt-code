# %%
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, threshold=50)

# %%
import imageio

dir_path = "../data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%6/99 files (6.1%10/99 files (10.1%15/99 files (15.2%19/99 files (19.2%23/99 files (23.2%28/99 files (28.3%32/99 files (32.3%36/99 files (36.4%40/99 files (40.4%42/99 files (42.4%46/99 files (46.5%50/99 files (50.5%54/99 files (54.5%58/99 files (58.6%62/99 files (62.6%65/99 files (65.7%69/99 files (69.7%73/99 files (73.7%77/99 files (77.8%81/99 files (81.8%85/99 files (85.9%89/99 files (89.9%94/99 files (94.9%99/99 files (100.099/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 4/99  (4.09/99  (9.113/99  (13.119/99  (19.226/99  (26.330/99  (30.335/99  (35.439/99  (39.443/99  (43.447/99  (47.550/99  (50.554/99  (54.559/99  (59.664/99  (64.669/99  (69.774/99  (74.779/99  (79.882/99  (82.885/99  (85.986/99  (86.989/99  (89.994/99  (94.997/99  (98.099/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)

vol.shape
# Out:
# torch.Size([1, 99, 512, 512])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(vol_arr[50])

# %%
plt.imshow(vol_arr[20])
